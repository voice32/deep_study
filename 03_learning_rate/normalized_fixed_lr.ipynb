# %%
'''Trains a simple deep NN on the MNIST dataset.
Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''
import keras
import keras.backend as K
from keras.datasets import mnist
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Dropout, Activation
from keras.optimizers import RMSprop
from keras.callbacks import CSVLogger, ReduceLROnPlateau
import os
from keras.layers.noise import AlphaDropout
import keras.activations

import numpy as np
from scipy import stats
import pandas as pd
import time
# Out:
# C:\Users\MaksutovRN\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
batch_size = 64
num_classes = 10
epochs = 200
units = 64
experiments = 5
start = 0

activations = ['selu', 'sigmoid']
optimizers = ['Adamax', 'sgd']

lrs = [0.1, 0.01, 0.002, 0.001]

# %%
# the data, shuffled and split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %%
start_time = time.time()
counter = 0
total_items = len(activations) * len(optimizers) * experiments * len(lrs)

for lr in lrs:
    for act in activations:
        for opt in optimizers:
            print("Training for activation " + act + " with optimizer " + opt + " and lr = " + str(lr))
            for i in range(experiments):

                act_dict = {
                  'sigmoid': Activation(keras.activations.sigmoid),
                  'selu': Activation(keras.activations.selu),
                }

                opt_dict = {
                  'sgd': keras.optimizers.SGD(lr=lr),
                  'Adamax': keras.optimizers.Adamax(lr=lr),
                }

                model_name = 'normd_fixed_' + str(lr) + "_" + act + "_" + opt + '_' + str(i + start)
                inputs = Input(shape=(784,))
                x = Dense(units, name = 'dense_1')(inputs)
                x = act_dict[act](x)
                x = Dropout(0.2)(x)
                x = Dense(units, name = 'dense_2')(x)
                x = act_dict[act](x)
                x = Dropout(0.2)(x)
                predictions = Dense(num_classes, activation='softmax', name = 'dense_output')(x)
                model = Model(inputs=inputs, outputs=predictions)

                model.compile(loss='categorical_crossentropy',
                                  optimizer=opt_dict[opt],
                                  metrics=['accuracy'])
                print('-'*30)
                print('Experiment', i)

                csv_logger = CSVLogger('./training_logs/%s_%d.csv' % (model_name, units), append=False)
                history = model.fit(x_train, y_train,
                                    batch_size=batch_size,
                                    epochs=epochs,
                                    verbose=0,
                                    validation_data=(x_test, y_test), callbacks=[csv_logger])

                score = model.evaluate(x_test, y_test, verbose=0)
                print('Test accuracy:', score[1])

                t = time.time()
                time_diff = t - start_time
                counter +=1
                rem_items = total_items - counter
                total_time = round((total_items / counter) * time_diff)
                rem_time = round(total_time - time_diff)
                m, s = divmod(rem_time, 60)
                h, m = divmod(m, 60)
                d, h = divmod(h, 24)
                print('Remaining time: %d days %d hours %02d minutes %02d seconds' % (d, h, m, s))
# Out:
# Training for activation selu with optimizer Adamax and lr = 0.1
# ------------------------------
# Experiment 0
# Test accuracy: 0.9643
# Remaining time: 0 days 10 hours 47 minutes 35 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9404
# Remaining time: 0 days 10 hours 31 minutes 52 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9574
# Remaining time: 0 days 10 hours 19 minutes 46 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9583
# Remaining time: 0 days 10 hours 14 minutes 28 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9456
# Remaining time: 0 days 10 hours 12 minutes 38 seconds
# Training for activation selu with optimizer sgd and lr = 0.1
# ------------------------------
# Experiment 0
# Test accuracy: 0.98
# Remaining time: 0 days 10 hours 04 minutes 39 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9793
# Remaining time: 0 days 9 hours 56 minutes 30 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9787
# Remaining time: 0 days 9 hours 49 minutes 19 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.98
# Remaining time: 0 days 9 hours 41 minutes 01 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9809
# Remaining time: 0 days 9 hours 29 minutes 57 seconds
# Training for activation sigmoid with optimizer Adamax and lr = 0.1
# ------------------------------
# Experiment 0
# Test accuracy: 0.97
# Remaining time: 0 days 9 hours 23 minutes 33 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.974
# Remaining time: 0 days 9 hours 18 minutes 07 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9734
# Remaining time: 0 days 9 hours 12 minutes 00 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9716
# Remaining time: 0 days 9 hours 05 minutes 37 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9708
# Remaining time: 0 days 8 hours 58 minutes 44 seconds
# Training for activation sigmoid with optimizer sgd and lr = 0.1
# ------------------------------
# Experiment 0
# Test accuracy: 0.9772
# Remaining time: 0 days 8 hours 49 minutes 57 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9769
# Remaining time: 0 days 8 hours 41 minutes 00 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.977
# Remaining time: 0 days 8 hours 33 minutes 15 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9764
# Remaining time: 0 days 8 hours 24 minutes 54 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9758
# Remaining time: 0 days 8 hours 16 minutes 40 seconds
# Training for activation selu with optimizer Adamax and lr = 0.01
# ------------------------------
# Experiment 0
# Test accuracy: 0.9794
# Remaining time: 0 days 8 hours 12 minutes 26 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9795
# Remaining time: 0 days 8 hours 07 minutes 59 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9799
# Remaining time: 0 days 8 hours 02 minutes 27 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9793
# Remaining time: 0 days 7 hours 56 minutes 47 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9812
# Remaining time: 0 days 7 hours 51 minutes 59 seconds
# Training for activation selu with optimizer sgd and lr = 0.01
# ------------------------------
# Experiment 0
# Test accuracy: 0.9725
# Remaining time: 0 days 7 hours 44 minutes 49 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9732
# Remaining time: 0 days 7 hours 37 minutes 33 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.971
# Remaining time: 0 days 7 hours 30 minutes 18 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9711
# Remaining time: 0 days 7 hours 23 minutes 08 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9721
# Remaining time: 0 days 7 hours 15 minutes 51 seconds
# Training for activation sigmoid with optimizer Adamax and lr = 0.01
# ------------------------------
# Experiment 0
# Test accuracy: 0.9766
# Remaining time: 0 days 7 hours 09 minutes 14 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.974
# Remaining time: 0 days 7 hours 02 minutes 23 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9764
# Remaining time: 0 days 6 hours 55 minutes 10 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9769
# Remaining time: 0 days 6 hours 48 minutes 13 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9744
# Remaining time: 0 days 6 hours 41 minutes 02 seconds
# Training for activation sigmoid with optimizer sgd and lr = 0.01
# ------------------------------
# Experiment 0
# Test accuracy: 0.954
# Remaining time: 0 days 6 hours 32 minutes 41 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.951
# Remaining time: 0 days 6 hours 24 minutes 37 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9517
# Remaining time: 0 days 6 hours 16 minutes 43 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9518
# Remaining time: 0 days 6 hours 08 minutes 36 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9532
# Remaining time: 0 days 6 hours 00 minutes 12 seconds
# Training for activation selu with optimizer Adamax and lr = 0.002
# ------------------------------
# Experiment 0
# Test accuracy: 0.9813
# Remaining time: 0 days 5 hours 53 minutes 21 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9803
# Remaining time: 0 days 5 hours 46 minutes 00 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9806
# Remaining time: 0 days 5 hours 38 minutes 39 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9805
# Remaining time: 0 days 5 hours 31 minutes 13 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9789
# Remaining time: 0 days 5 hours 23 minutes 51 seconds
# Training for activation selu with optimizer sgd and lr = 0.002
# ------------------------------
# Experiment 0
# Test accuracy: 0.9517
# Remaining time: 0 days 5 hours 15 minutes 39 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9524
# Remaining time: 0 days 5 hours 07 minutes 27 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9493
# Remaining time: 0 days 4 hours 59 minutes 19 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.949
# Remaining time: 0 days 4 hours 50 minutes 47 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9507
# Remaining time: 0 days 4 hours 42 minutes 57 seconds
# Training for activation sigmoid with optimizer Adamax and lr = 0.002
# ------------------------------
# Experiment 0
# Test accuracy: 0.977
# Remaining time: 0 days 4 hours 35 minutes 55 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9777
# Remaining time: 0 days 4 hours 28 minutes 33 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9764
# Remaining time: 0 days 4 hours 21 minutes 07 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9767
# Remaining time: 0 days 4 hours 13 minutes 27 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9773
# Remaining time: 0 days 4 hours 05 minutes 34 seconds
# Training for activation sigmoid with optimizer sgd and lr = 0.002
# ------------------------------
# Experiment 0
# Test accuracy: 0.9077
# Remaining time: 0 days 3 hours 57 minutes 02 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9067
# Remaining time: 0 days 3 hours 48 minutes 30 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9078
# Remaining time: 0 days 3 hours 39 minutes 54 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9099
# Remaining time: 0 days 3 hours 31 minutes 07 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9069
# Remaining time: 0 days 3 hours 22 minutes 13 seconds
# Training for activation selu with optimizer Adamax and lr = 0.001
# ------------------------------
# Experiment 0
# Test accuracy: 0.9794
# Remaining time: 0 days 3 hours 13 minutes 42 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9787
# Remaining time: 0 days 3 hours 04 minutes 54 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9796
# Remaining time: 0 days 2 hours 55 minutes 52 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9789
# Remaining time: 0 days 2 hours 46 minutes 43 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9779
# Remaining time: 0 days 2 hours 37 minutes 25 seconds
# Training for activation selu with optimizer sgd and lr = 0.001
# ------------------------------
# Experiment 0
# Test accuracy: 0.9381
# Remaining time: 0 days 2 hours 27 minutes 51 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9332
# Remaining time: 0 days 2 hours 18 minutes 06 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9383
# Remaining time: 0 days 2 hours 08 minutes 11 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9353
# Remaining time: 0 days 1 hours 58 minutes 09 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9383
# Remaining time: 0 days 1 hours 48 minutes 00 seconds
# Training for activation sigmoid with optimizer Adamax and lr = 0.001
# ------------------------------
# Experiment 0
# Test accuracy: 0.9757
# Remaining time: 0 days 1 hours 37 minutes 46 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.976
# Remaining time: 0 days 1 hours 27 minutes 22 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9765
# Remaining time: 0 days 1 hours 16 minutes 55 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9779
# Remaining time: 0 days 1 hours 06 minutes 19 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9768
# Remaining time: 0 days 0 hours 55 minutes 34 seconds
# Training for activation sigmoid with optimizer sgd and lr = 0.001
# ------------------------------
# Experiment 0
# Test accuracy: 0.8765
# Remaining time: 0 days 0 hours 44 minutes 40 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.8811
# Remaining time: 0 days 0 hours 33 minutes 39 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.8746
# Remaining time: 0 days 0 hours 22 minutes 32 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.871
# Remaining time: 0 days 0 hours 11 minutes 18 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.8683
# Remaining time: 0 days 0 hours 00 minutes 00 seconds
