# %%
'''Trains a simple deep NN on the MNIST dataset.
Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''
import keras
import keras.backend as K
from keras.datasets import mnist
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Dropout, Activation, GaussianDropout, GaussianNoise
from keras.optimizers import RMSprop
from keras.callbacks import CSVLogger, Callback, ReduceLROnPlateau
import os
from keras.layers.noise import AlphaDropout
import keras.activations
import numpy as np
from scipy import stats
import pandas as pd
import time
# Out:
# C:\Users\MaksutovRN\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

num_classes = 10

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

def standardize_sample_wise(dataset):
    standardized = []
    for s in dataset:
        mean, std = s.mean(), s.std()
        s = (s - mean) / std
        standardized.append(s)
    return np.array(standardized)

x_train = standardize_sample_wise(x_train)
x_test = standardize_sample_wise(x_test)
# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
batch_size = 64

epochs = 100
units = 64
experiments = 5
start = 0
activations = ['selu', 'sigmoid']
optimizers = ['Adamax', 'sgd']

configs = [
    {
        'type': 'no_dropout',
        'rate': 0.0
    },
#     This has been done in 02_optimizers
#     {
#         'type': 'dropout',
#         'rate': 0.2
#     },
    {
        'type': 'dropout',
        'rate': 0.35
    },
    {
        'type': 'dropout',
        'rate': 0.5
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.2
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.35
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.5
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.2
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.35
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.5
    }
]

# %%
configs = [
    {
        'type': 'dropout',
        'rate': 0.1
    },
    {
        'type': 'dropout',
        'rate': 0.7
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.1
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.7
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.1
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.7
    },
    {
        'type': 'gaussian_noise',
        'rate': 0.05
    },
    {
        'type': 'gaussian_noise',
        'rate': 0.5
    },
    {
        'type': 'gaussian_noise',
        'rate': 1.0
    }
]

# %%
start_time = time.time()
counter = 0
total_items = (len(activations))* len(optimizers) * experiments * len(configs)

for cfg in configs:

    for act in activations:
        for opt in optimizers:
            print("Training for activation " + act + ", optimizer " + opt + " with config " + str(cfg))

            for i in range(experiments):
                K.clear_session()
                K.reset_uids()
                # Selecting activation function
                act_dict = {
                  'sigmoid': Activation(keras.activations.sigmoid),
                  'tanh': Activation(keras.activations.tanh),
                  'relu': Activation(keras.activations.relu),
                  'linear': Activation(keras.activations.linear),
                  'elu': Activation(keras.activations.elu),
                  'softplus': Activation(keras.activations.softplus),
                  'softsign': Activation(keras.activations.softsign),
                  'hard_sigmoid': Activation(keras.activations.hard_sigmoid),
                  'LeakyReLU': keras.layers.advanced_activations.LeakyReLU(),
                  'selu': Activation(keras.activations.selu),
                  'ThresholdedReLU': keras.layers.advanced_activations.ThresholdedReLU(theta=0.7) 
                }

                # Selecting optimizer
                opt_dict = {
                  'rmsp': keras.optimizers.rmsprop(lr=0.001),
                  'adam': keras.optimizers.Adam(),
                  'sgd': keras.optimizers.SGD(),
                  'Adagrad': keras.optimizers.Adagrad(),
                  'Adadelta': keras.optimizers.Adadelta(),
                  'Adamax': keras.optimizers.Adamax(),
                  'Nadam': keras.optimizers.Nadam()
                }


                model_name = 'std_%s_%0.2f_%s_%s_%d_%d' % (cfg['type'], cfg['rate'], act, opt, (i + start), units)
                inputs = Input(shape=(784,))
                x = Dense(units, name = 'dense_1')(inputs)
                x = act_dict[act](x)
                
                if cfg['type'] == 'dropout':
                    x = Dropout(cfg['rate'])(x)
                elif cfg['type'] == 'alpha_dropout':
                    x = AlphaDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_dropout':
                    x = GaussianDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_noise':
                    x = GaussianDropout(cfg['rate'])(x)
                    
                x = Dense(units, name = 'dense_2')(x)
                x = act_dict[act](x)
                
                if cfg['type'] == 'dropout':
                    x = Dropout(cfg['rate'])(x)
                elif cfg['type'] == 'alpha_dropout':
                    x = AlphaDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_dropout':
                    x = GaussianDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_noise':
                    x = GaussianDropout(cfg['rate'])(x)
    
                predictions = Dense(num_classes, activation='softmax', name = 'dense_output')(x)
                model = Model(inputs=inputs, outputs=predictions)

                model.compile(loss='categorical_crossentropy',
                                  optimizer=opt_dict[opt],
                                  metrics=['accuracy'])
                print('-'*30)
                print('Experiment', i)

                csv_logger = CSVLogger('./training_logs/%s.csv' % (model_name), append=False)
                history = model.fit(x_train, y_train,
                                    batch_size=batch_size,
                                    epochs=epochs,
                                    verbose=0,
                                    validation_data=(x_test, y_test), callbacks=[csv_logger])

                score = model.evaluate(x_test, y_test, verbose=0)
                
                print('Test accuracy:', score[1])

                t = time.time()
                time_diff = t - start_time
                counter +=1
                rem_items = total_items - counter
                total_time = round((total_items / counter) * time_diff)
                rem_time = round(total_time - time_diff)
                m, s = divmod(rem_time, 60)
                h, m = divmod(m, 60)
                d, h = divmod(h, 24)
                print('Remaining time: %d days %d hours %02d minutes %02d seconds' % (d, h, m, s))
# Out:
# Training for activation selu, optimizer Adamax with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9808
# Remaining time: 0 days 15 hours 15 minutes 15 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9816
# Remaining time: 0 days 15 hours 16 minutes 55 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9813
# Remaining time: 0 days 15 hours 23 minutes 41 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9803
# Remaining time: 0 days 15 hours 19 minutes 05 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9818
# Remaining time: 0 days 15 hours 13 minutes 07 seconds
# Training for activation selu, optimizer sgd with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9778
# Remaining time: 0 days 15 hours 01 minutes 02 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9786
# Remaining time: 0 days 14 hours 50 minutes 25 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9794
# Remaining time: 0 days 14 hours 41 minutes 55 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9809
# Remaining time: 0 days 14 hours 33 minutes 57 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9789
# Remaining time: 0 days 14 hours 32 minutes 52 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9768
# Remaining time: 0 days 14 hours 32 minutes 24 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9747
# Remaining time: 0 days 14 hours 29 minutes 47 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9773
# Remaining time: 0 days 14 hours 25 minutes 14 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9737
# Remaining time: 0 days 14 hours 21 minutes 17 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9744
# Remaining time: 0 days 14 hours 15 minutes 09 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9622
# Remaining time: 0 days 14 hours 06 minutes 50 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9619
# Remaining time: 0 days 14 hours 01 minutes 04 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9647
# Remaining time: 0 days 13 hours 54 minutes 37 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9621
# Remaining time: 0 days 13 hours 47 minutes 41 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9636
# Remaining time: 0 days 13 hours 40 minutes 56 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.952
# Remaining time: 0 days 13 hours 33 minutes 41 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9535
# Remaining time: 0 days 13 hours 25 minutes 57 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9521
# Remaining time: 0 days 13 hours 18 minutes 39 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9529
# Remaining time: 0 days 13 hours 11 minutes 51 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9531
# Remaining time: 0 days 13 hours 04 minutes 10 seconds
# Training for activation selu, optimizer sgd with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9424
# Remaining time: 0 days 12 hours 55 minutes 34 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9416
# Remaining time: 0 days 12 hours 47 minutes 22 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9405
# Remaining time: 0 days 12 hours 39 minutes 20 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9386
# Remaining time: 0 days 12 hours 31 minutes 44 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9407
# Remaining time: 0 days 12 hours 25 minutes 26 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9368
# Remaining time: 0 days 12 hours 19 minutes 25 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9394
# Remaining time: 0 days 12 hours 13 minutes 29 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9428
# Remaining time: 0 days 12 hours 07 minutes 39 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9405
# Remaining time: 0 days 12 hours 01 minutes 43 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9376
# Remaining time: 0 days 11 hours 55 minutes 27 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9133
# Remaining time: 0 days 11 hours 48 minutes 34 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9131
# Remaining time: 0 days 11 hours 41 minutes 45 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9177
# Remaining time: 0 days 11 hours 34 minutes 58 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.913
# Remaining time: 0 days 11 hours 28 minutes 21 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9157
# Remaining time: 0 days 11 hours 22 minutes 09 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9795
# Remaining time: 0 days 11 hours 17 minutes 10 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9802
# Remaining time: 0 days 11 hours 12 minutes 11 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9804
# Remaining time: 0 days 11 hours 07 minutes 11 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9804
# Remaining time: 0 days 11 hours 02 minutes 17 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9786
# Remaining time: 0 days 10 hours 56 minutes 53 seconds
# Training for activation selu, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9783
# Remaining time: 0 days 10 hours 51 minutes 01 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9789
# Remaining time: 0 days 10 hours 45 minutes 07 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9798
# Remaining time: 0 days 10 hours 39 minutes 17 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9773
# Remaining time: 0 days 10 hours 33 minutes 38 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9789
# Remaining time: 0 days 10 hours 28 minutes 32 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.936
# Remaining time: 0 days 10 hours 23 minutes 39 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.936
# Remaining time: 0 days 10 hours 18 minutes 46 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9392
# Remaining time: 0 days 10 hours 13 minutes 45 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9352
# Remaining time: 0 days 10 hours 08 minutes 44 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9354
# Remaining time: 0 days 10 hours 03 minutes 40 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.8966
# Remaining time: 0 days 9 hours 57 minutes 48 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.8962
# Remaining time: 0 days 9 hours 52 minutes 00 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.8985
# Remaining time: 0 days 9 hours 46 minutes 26 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.8911
# Remaining time: 0 days 9 hours 40 minutes 47 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9008
# Remaining time: 0 days 9 hours 35 minutes 07 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9382
# Remaining time: 0 days 9 hours 30 minutes 46 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9347
# Remaining time: 0 days 9 hours 26 minutes 27 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9346
# Remaining time: 0 days 9 hours 22 minutes 07 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.936
# Remaining time: 0 days 9 hours 17 minutes 53 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.937
# Remaining time: 0 days 9 hours 13 minutes 36 seconds
# Training for activation selu, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.921
# Remaining time: 0 days 9 hours 08 minutes 43 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9214
# Remaining time: 0 days 9 hours 03 minutes 45 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9189
# Remaining time: 0 days 8 hours 58 minutes 48 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9189
# Remaining time: 0 days 8 hours 53 minutes 48 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9229
# Remaining time: 0 days 8 hours 48 minutes 55 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.1921
# Remaining time: 0 days 8 hours 43 minutes 58 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.197
# Remaining time: 0 days 8 hours 39 minutes 13 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.2109
# Remaining time: 0 days 8 hours 34 minutes 25 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.1937
# Remaining time: 0 days 8 hours 29 minutes 38 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.2101
# Remaining time: 0 days 8 hours 24 minutes 46 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.1148
# Remaining time: 0 days 8 hours 19 minutes 38 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.1969
# Remaining time: 0 days 8 hours 14 minutes 27 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.1135
# Remaining time: 0 days 8 hours 09 minutes 14 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.1135
# Remaining time: 0 days 8 hours 03 minutes 54 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.1135
# Remaining time: 0 days 7 hours 58 minutes 39 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9798
# Remaining time: 0 days 7 hours 54 minutes 44 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9792
# Remaining time: 0 days 7 hours 50 minutes 45 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9819
# Remaining time: 0 days 7 hours 46 minutes 46 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9804
# Remaining time: 0 days 7 hours 42 minutes 46 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9813
# Remaining time: 0 days 7 hours 38 minutes 43 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9792
# Remaining time: 0 days 7 hours 34 minutes 28 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.98
# Remaining time: 0 days 7 hours 30 minutes 05 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.98
# Remaining time: 0 days 7 hours 25 minutes 37 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.98
# Remaining time: 0 days 7 hours 21 minutes 10 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9796
# Remaining time: 0 days 7 hours 16 minutes 39 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9737
# Remaining time: 0 days 7 hours 12 minutes 07 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9764
# Remaining time: 0 days 7 hours 07 minutes 42 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9777
# Remaining time: 0 days 7 hours 03 minutes 20 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9739
# Remaining time: 0 days 6 hours 58 minutes 59 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9758
# Remaining time: 0 days 6 hours 54 minutes 35 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9653
# Remaining time: 0 days 6 hours 49 minutes 53 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9617
# Remaining time: 0 days 6 hours 45 minutes 10 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.966
# Remaining time: 0 days 6 hours 40 minutes 23 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9651
# Remaining time: 0 days 6 hours 35 minutes 34 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9647
# Remaining time: 0 days 6 hours 30 minutes 46 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9511
# Remaining time: 0 days 6 hours 26 minutes 21 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.947
# Remaining time: 0 days 6 hours 21 minutes 53 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9489
# Remaining time: 0 days 6 hours 17 minutes 28 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9505
# Remaining time: 0 days 6 hours 13 minutes 02 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9478
# Remaining time: 0 days 6 hours 08 minutes 33 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.934
# Remaining time: 0 days 6 hours 03 minutes 56 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9378
# Remaining time: 0 days 5 hours 59 minutes 16 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9372
# Remaining time: 0 days 5 hours 54 minutes 30 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9363
# Remaining time: 0 days 5 hours 49 minutes 45 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.937
# Remaining time: 0 days 5 hours 44 minutes 59 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9417
# Remaining time: 0 days 5 hours 40 minutes 14 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9431
# Remaining time: 0 days 5 hours 35 minutes 32 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9412
# Remaining time: 0 days 5 hours 30 minutes 52 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9407
# Remaining time: 0 days 5 hours 26 minutes 12 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9414
# Remaining time: 0 days 5 hours 21 minutes 31 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9087
# Remaining time: 0 days 5 hours 16 minutes 39 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9099
# Remaining time: 0 days 5 hours 11 minutes 45 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9083
# Remaining time: 0 days 5 hours 06 minutes 51 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9131
# Remaining time: 0 days 5 hours 01 minutes 54 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9053
# Remaining time: 0 days 4 hours 56 minutes 58 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9796
# Remaining time: 0 days 4 hours 52 minutes 16 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.98
# Remaining time: 0 days 4 hours 47 minutes 33 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9817
# Remaining time: 0 days 4 hours 42 minutes 53 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9794
# Remaining time: 0 days 4 hours 38 minutes 13 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9797
# Remaining time: 0 days 4 hours 33 minutes 30 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9793
# Remaining time: 0 days 4 hours 28 minutes 41 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9784
# Remaining time: 0 days 4 hours 23 minutes 50 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9782
# Remaining time: 0 days 4 hours 18 minutes 56 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9781
# Remaining time: 0 days 4 hours 14 minutes 02 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9787
# Remaining time: 0 days 4 hours 09 minutes 07 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9747
# Remaining time: 0 days 4 hours 04 minutes 13 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9746
# Remaining time: 0 days 3 hours 59 minutes 20 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9744
# Remaining time: 0 days 3 hours 54 minutes 26 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9759
# Remaining time: 0 days 3 hours 49 minutes 32 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9739
# Remaining time: 0 days 3 hours 44 minutes 37 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9652
# Remaining time: 0 days 3 hours 39 minutes 37 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9657
# Remaining time: 0 days 3 hours 34 minutes 36 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9663
# Remaining time: 0 days 3 hours 29 minutes 35 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9665
# Remaining time: 0 days 3 hours 24 minutes 35 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9668
# Remaining time: 0 days 3 hours 19 minutes 33 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9712
# Remaining time: 0 days 3 hours 14 minutes 40 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9705
# Remaining time: 0 days 3 hours 09 minutes 47 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9706
# Remaining time: 0 days 3 hours 04 minutes 54 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9712
# Remaining time: 0 days 2 hours 59 minutes 59 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9702
# Remaining time: 0 days 2 hours 55 minutes 03 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9616
# Remaining time: 0 days 2 hours 50 minutes 05 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9634
# Remaining time: 0 days 2 hours 45 minutes 07 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9645
# Remaining time: 0 days 2 hours 39 minutes 51 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9632
# Remaining time: 0 days 2 hours 34 minutes 34 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9656
# Remaining time: 0 days 2 hours 29 minutes 18 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9595
# Remaining time: 0 days 2 hours 24 minutes 05 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9609
# Remaining time: 0 days 2 hours 18 minutes 51 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9618
# Remaining time: 0 days 2 hours 13 minutes 40 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9622
# Remaining time: 0 days 2 hours 08 minutes 29 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9629
# Remaining time: 0 days 2 hours 03 minutes 19 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9382
# Remaining time: 0 days 1 hours 58 minutes 09 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.939
# Remaining time: 0 days 1 hours 52 minutes 59 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9446
# Remaining time: 0 days 1 hours 47 minutes 53 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9418
# Remaining time: 0 days 1 hours 42 minutes 46 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9415
# Remaining time: 0 days 1 hours 37 minutes 41 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9781
# Remaining time: 0 days 1 hours 32 minutes 36 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9781
# Remaining time: 0 days 1 hours 27 minutes 31 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9793
# Remaining time: 0 days 1 hours 22 minutes 28 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9771
# Remaining time: 0 days 1 hours 17 minutes 27 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9776
# Remaining time: 0 days 1 hours 12 minutes 27 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9759
# Remaining time: 0 days 1 hours 07 minutes 27 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9735
# Remaining time: 0 days 1 hours 02 minutes 29 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9754
# Remaining time: 0 days 0 hours 57 minutes 32 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9762
# Remaining time: 0 days 0 hours 52 minutes 37 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9759
# Remaining time: 0 days 0 hours 47 minutes 44 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9739
# Remaining time: 0 days 0 hours 42 minutes 51 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9714
# Remaining time: 0 days 0 hours 38 minutes 00 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9729
# Remaining time: 0 days 0 hours 33 minutes 11 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9719
# Remaining time: 0 days 0 hours 28 minutes 22 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9725
# Remaining time: 0 days 0 hours 23 minutes 36 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9686
# Remaining time: 0 days 0 hours 18 minutes 49 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9674
# Remaining time: 0 days 0 hours 14 minutes 05 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9691
# Remaining time: 0 days 0 hours 09 minutes 22 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9687
# Remaining time: 0 days 0 hours 04 minutes 40 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9671
# Remaining time: 0 days 0 hours 00 minutes 00 seconds
