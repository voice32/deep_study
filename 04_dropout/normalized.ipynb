# %%
'''Trains a simple deep NN on the MNIST dataset.
Gets to 98.40% test accuracy after 20 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''
import keras
import keras.backend as K
from keras.datasets import mnist
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Dropout, Activation, GaussianDropout, GaussianNoise
from keras.optimizers import RMSprop
from keras.callbacks import CSVLogger, Callback, ReduceLROnPlateau
import os
from keras.layers.noise import AlphaDropout
import keras.activations
import numpy as np
from scipy import stats
import pandas as pd
import time
# Out:
# C:\Users\MaksutovRN\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

num_classes = 10

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
x_train_mean = np.mean(x_train)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# print(stats.describe(x_train.reshape(60000 * 784, )))
# print(stats.describe(y_train.reshape(60000 * 10, )))
# print(stats.describe(x_test.reshape(10000 * 784, )))
# print(stats.describe(y_test.reshape(10000 * 10, )))
# Out:
# 60000 train samples
# 10000 test samples

# %%
batch_size = 64

epochs = 100
units = 64
experiments = 5
start = 0
activations = ['selu', 'sigmoid']
optimizers = ['Adamax', 'sgd']

configs = [
    {
        'type': 'no_dropout',
        'rate': 0.0
    },
#     This has been done in 02_optimizers
#     {
#         'type': 'dropout',
#         'rate': 0.2
#     },
    {
        'type': 'dropout',
        'rate': 0.35
    },
    {
        'type': 'dropout',
        'rate': 0.5
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.2
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.35
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.5
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.2
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.35
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.5
    }
]

# %%
configs = [
    {
        'type': 'dropout',
        'rate': 0.1
    },
    {
        'type': 'dropout',
        'rate': 0.7
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.1
    },
    {
        'type': 'alpha_dropout',
        'rate': 0.7
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.1
    },
    {
        'type': 'gaussian_dropout',
        'rate': 0.7
    },
    {
        'type': 'gaussian_noise',
        'rate': 0.05
    },
    {
        'type': 'gaussian_noise',
        'rate': 0.5
    },
    {
        'type': 'gaussian_noise',
        'rate': 1.0
    }
]

# %%
start_time = time.time()
counter = 0
total_items = (len(activations))* len(optimizers) * experiments * len(configs)

for cfg in configs:

    for act in activations:
        for opt in optimizers:
            print("Training for activation " + act + ", optimizer " + opt + " with config " + str(cfg))

            for i in range(experiments):
                K.clear_session()
                K.reset_uids()
                # Selecting activation function
                act_dict = {
                  'sigmoid': Activation(keras.activations.sigmoid),
                  'tanh': Activation(keras.activations.tanh),
                  'relu': Activation(keras.activations.relu),
                  'linear': Activation(keras.activations.linear),
                  'elu': Activation(keras.activations.elu),
                  'softplus': Activation(keras.activations.softplus),
                  'softsign': Activation(keras.activations.softsign),
                  'hard_sigmoid': Activation(keras.activations.hard_sigmoid),
                  'LeakyReLU': keras.layers.advanced_activations.LeakyReLU(),
                  'selu': Activation(keras.activations.selu),
                  'ThresholdedReLU': keras.layers.advanced_activations.ThresholdedReLU(theta=0.7) 
                }

                # Selecting optimizer
                opt_dict = {
                  'rmsp': keras.optimizers.rmsprop(lr=0.001),
                  'adam': keras.optimizers.Adam(),
                  'sgd': keras.optimizers.SGD(),
                  'Adagrad': keras.optimizers.Adagrad(),
                  'Adadelta': keras.optimizers.Adadelta(),
                  'Adamax': keras.optimizers.Adamax(),
                  'Nadam': keras.optimizers.Nadam()
                }


                model_name = 'normd_%s_%0.2f_%s_%s_%d_%d' % (cfg['type'], cfg['rate'], act, opt, (i + start), units)
                inputs = Input(shape=(784,))
                x = Dense(units, name = 'dense_1')(inputs)
                x = act_dict[act](x)
                
                if cfg['type'] == 'dropout':
                    x = Dropout(cfg['rate'])(x)
                elif cfg['type'] == 'alpha_dropout':
                    x = AlphaDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_dropout':
                    x = GaussianDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_noise':
                    x = GaussianDropout(cfg['rate'])(x)   
                
                x = Dense(units, name = 'dense_2')(x)
                x = act_dict[act](x)
                
                if cfg['type'] == 'dropout':
                    x = Dropout(cfg['rate'])(x)
                elif cfg['type'] == 'alpha_dropout':
                    x = AlphaDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_dropout':
                    x = GaussianDropout(cfg['rate'])(x)
                elif cfg['type'] == 'gaussian_noise':
                    x = GaussianDropout(cfg['rate'])(x)
    
                predictions = Dense(num_classes, activation='softmax', name = 'dense_output')(x)
                model = Model(inputs=inputs, outputs=predictions)

                model.compile(loss='categorical_crossentropy',
                                  optimizer=opt_dict[opt],
                                  metrics=['accuracy'])
                print('-'*30)
                print('Experiment', i)

                csv_logger = CSVLogger('./training_logs/%s.csv' % (model_name), append=False)
                history = model.fit(x_train, y_train,
                                    batch_size=batch_size,
                                    epochs=epochs,
                                    verbose=0,
                                    validation_data=(x_test, y_test), callbacks=[csv_logger])

                score = model.evaluate(x_test, y_test, verbose=0)
                
                print('Test accuracy:', score[1])

                t = time.time()
                time_diff = t - start_time
                counter +=1
                rem_items = total_items - counter
                total_time = round((total_items / counter) * time_diff)
                rem_time = round(total_time - time_diff)
                m, s = divmod(rem_time, 60)
                h, m = divmod(m, 60)
                d, h = divmod(h, 24)
                print('Remaining time: %d days %d hours %02d minutes %02d seconds' % (d, h, m, s))
# Out:
# Training for activation selu, optimizer Adamax with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9805
# Remaining time: 0 days 12 hours 39 minutes 29 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9796
# Remaining time: 0 days 12 hours 15 minutes 04 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9804
# Remaining time: 0 days 12 hours 07 minutes 02 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9828
# Remaining time: 0 days 12 hours 03 minutes 50 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9796
# Remaining time: 0 days 12 hours 06 minutes 14 seconds
# Training for activation selu, optimizer sgd with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9735
# Remaining time: 0 days 11 hours 55 minutes 25 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9727
# Remaining time: 0 days 11 hours 44 minutes 14 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9727
# Remaining time: 0 days 11 hours 35 minutes 15 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9736
# Remaining time: 0 days 11 hours 31 minutes 43 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9724
# Remaining time: 0 days 11 hours 25 minutes 13 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9777
# Remaining time: 0 days 11 hours 18 minutes 59 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9757
# Remaining time: 0 days 11 hours 13 minutes 10 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9791
# Remaining time: 0 days 11 hours 08 minutes 32 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9781
# Remaining time: 0 days 11 hours 04 minutes 08 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.977
# Remaining time: 0 days 10 hours 59 minutes 57 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9423
# Remaining time: 0 days 10 hours 52 minutes 02 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9396
# Remaining time: 0 days 10 hours 44 minutes 04 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9415
# Remaining time: 0 days 10 hours 38 minutes 24 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9409
# Remaining time: 0 days 10 hours 32 minutes 16 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9417
# Remaining time: 0 days 10 hours 26 minutes 12 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.933
# Remaining time: 0 days 10 hours 24 minutes 08 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9332
# Remaining time: 0 days 10 hours 21 minutes 50 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9312
# Remaining time: 0 days 10 hours 19 minutes 12 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9347
# Remaining time: 0 days 10 hours 16 minutes 34 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9303
# Remaining time: 0 days 10 hours 13 minutes 55 seconds
# Training for activation selu, optimizer sgd with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9131
# Remaining time: 0 days 10 hours 09 minutes 34 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9145
# Remaining time: 0 days 10 hours 04 minutes 57 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9174
# Remaining time: 0 days 10 hours 00 minutes 58 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9149
# Remaining time: 0 days 9 hours 56 minutes 38 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9135
# Remaining time: 0 days 9 hours 53 minutes 00 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9343
# Remaining time: 0 days 9 hours 49 minutes 05 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9393
# Remaining time: 0 days 9 hours 49 minutes 42 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9361
# Remaining time: 0 days 9 hours 50 minutes 46 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9336
# Remaining time: 0 days 9 hours 51 minutes 56 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9383
# Remaining time: 0 days 9 hours 52 minutes 44 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.8622
# Remaining time: 0 days 9 hours 52 minutes 39 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.8677
# Remaining time: 0 days 9 hours 51 minutes 48 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.8683
# Remaining time: 0 days 9 hours 50 minutes 28 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.8731
# Remaining time: 0 days 9 hours 49 minutes 03 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.8687
# Remaining time: 0 days 9 hours 47 minutes 16 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9807
# Remaining time: 0 days 9 hours 47 minutes 03 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9796
# Remaining time: 0 days 9 hours 46 minutes 59 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9796
# Remaining time: 0 days 9 hours 46 minutes 28 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9805
# Remaining time: 0 days 9 hours 45 minutes 30 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9789
# Remaining time: 0 days 9 hours 44 minutes 27 seconds
# Training for activation selu, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9728
# Remaining time: 0 days 9 hours 42 minutes 26 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9706
# Remaining time: 0 days 9 hours 39 minutes 53 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9733
# Remaining time: 0 days 9 hours 37 minutes 41 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9706
# Remaining time: 0 days 9 hours 35 minutes 09 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9726
# Remaining time: 0 days 9 hours 32 minutes 19 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9361
# Remaining time: 0 days 9 hours 29 minutes 32 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9326
# Remaining time: 0 days 9 hours 26 minutes 10 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9346
# Remaining time: 0 days 9 hours 22 minutes 28 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9336
# Remaining time: 0 days 9 hours 18 minutes 44 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9369
# Remaining time: 0 days 9 hours 15 minutes 04 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.7649
# Remaining time: 0 days 9 hours 10 minutes 56 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.7615
# Remaining time: 0 days 9 hours 06 minutes 31 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.7781
# Remaining time: 0 days 9 hours 02 minutes 04 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.8019
# Remaining time: 0 days 8 hours 57 minutes 36 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.8281
# Remaining time: 0 days 8 hours 53 minutes 09 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9265
# Remaining time: 0 days 8 hours 49 minutes 21 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9301
# Remaining time: 0 days 8 hours 45 minutes 35 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9273
# Remaining time: 0 days 8 hours 41 minutes 47 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9314
# Remaining time: 0 days 8 hours 38 minutes 00 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9298
# Remaining time: 0 days 8 hours 34 minutes 08 seconds
# Training for activation selu, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.8804
# Remaining time: 0 days 8 hours 29 minutes 57 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.8729
# Remaining time: 0 days 8 hours 25 minutes 32 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.8833
# Remaining time: 0 days 8 hours 21 minutes 05 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.855
# Remaining time: 0 days 8 hours 16 minutes 36 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.8881
# Remaining time: 0 days 8 hours 12 minutes 07 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.2096
# Remaining time: 0 days 8 hours 07 minutes 48 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.1932
# Remaining time: 0 days 8 hours 03 minutes 46 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.2102
# Remaining time: 0 days 7 hours 59 minutes 43 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.21
# Remaining time: 0 days 7 hours 55 minutes 39 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.2106
# Remaining time: 0 days 7 hours 51 minutes 37 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'alpha_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.1135
# Remaining time: 0 days 7 hours 47 minutes 18 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.1135
# Remaining time: 0 days 7 hours 42 minutes 47 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.1135
# Remaining time: 0 days 7 hours 38 minutes 13 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.1135
# Remaining time: 0 days 7 hours 33 minutes 39 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.101
# Remaining time: 0 days 7 hours 29 minutes 07 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9806
# Remaining time: 0 days 7 hours 25 minutes 47 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9801
# Remaining time: 0 days 7 hours 22 minutes 25 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.981
# Remaining time: 0 days 7 hours 19 minutes 03 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9811
# Remaining time: 0 days 7 hours 15 minutes 34 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9817
# Remaining time: 0 days 7 hours 12 minutes 01 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9733
# Remaining time: 0 days 7 hours 08 minutes 09 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9724
# Remaining time: 0 days 7 hours 04 minutes 13 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9723
# Remaining time: 0 days 7 hours 00 minutes 12 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9742
# Remaining time: 0 days 6 hours 56 minutes 13 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.973
# Remaining time: 0 days 6 hours 52 minutes 15 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9791
# Remaining time: 0 days 6 hours 48 minutes 17 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9793
# Remaining time: 0 days 6 hours 44 minutes 18 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9777
# Remaining time: 0 days 6 hours 40 minutes 17 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9785
# Remaining time: 0 days 6 hours 36 minutes 16 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.98
# Remaining time: 0 days 6 hours 32 minutes 10 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.1}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9416
# Remaining time: 0 days 6 hours 27 minutes 48 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9398
# Remaining time: 0 days 6 hours 23 minutes 28 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9432
# Remaining time: 0 days 6 hours 19 minutes 02 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9379
# Remaining time: 0 days 6 hours 14 minutes 38 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9409
# Remaining time: 0 days 6 hours 10 minutes 12 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9273
# Remaining time: 0 days 6 hours 06 minutes 10 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.929
# Remaining time: 0 days 6 hours 02 minutes 08 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9298
# Remaining time: 0 days 5 hours 58 minutes 05 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9311
# Remaining time: 0 days 5 hours 54 minutes 01 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9265
# Remaining time: 0 days 5 hours 49 minutes 49 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9132
# Remaining time: 0 days 5 hours 45 minutes 29 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9128
# Remaining time: 0 days 5 hours 41 minutes 10 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9129
# Remaining time: 0 days 5 hours 36 minutes 47 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9143
# Remaining time: 0 days 5 hours 32 minutes 33 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.911
# Remaining time: 0 days 5 hours 28 minutes 19 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9382
# Remaining time: 0 days 5 hours 24 minutes 03 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9369
# Remaining time: 0 days 5 hours 19 minutes 47 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9355
# Remaining time: 0 days 5 hours 15 minutes 29 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9389
# Remaining time: 0 days 5 hours 11 minutes 06 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9351
# Remaining time: 0 days 5 hours 06 minutes 43 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_dropout', 'rate': 0.7}
# ------------------------------
# Experiment 0
# Test accuracy: 0.8656
# Remaining time: 0 days 5 hours 02 minutes 08 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.8665
# Remaining time: 0 days 4 hours 57 minutes 33 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.865
# Remaining time: 0 days 4 hours 52 minutes 58 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.8667
# Remaining time: 0 days 4 hours 48 minutes 26 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.8664
# Remaining time: 0 days 4 hours 43 minutes 53 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.979
# Remaining time: 0 days 4 hours 39 minutes 33 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9802
# Remaining time: 0 days 4 hours 35 minutes 10 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9799
# Remaining time: 0 days 4 hours 30 minutes 48 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9799
# Remaining time: 0 days 4 hours 26 minutes 22 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9775
# Remaining time: 0 days 4 hours 21 minutes 54 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9767
# Remaining time: 0 days 4 hours 17 minutes 19 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9752
# Remaining time: 0 days 4 hours 12 minutes 43 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.976
# Remaining time: 0 days 4 hours 08 minutes 07 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9756
# Remaining time: 0 days 4 hours 03 minutes 34 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9729
# Remaining time: 0 days 3 hours 59 minutes 01 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9775
# Remaining time: 0 days 3 hours 54 minutes 29 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9771
# Remaining time: 0 days 3 hours 49 minutes 55 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9768
# Remaining time: 0 days 3 hours 45 minutes 21 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9798
# Remaining time: 0 days 3 hours 40 minutes 44 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9781
# Remaining time: 0 days 3 hours 36 minutes 05 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.05}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9442
# Remaining time: 0 days 3 hours 31 minutes 22 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9433
# Remaining time: 0 days 3 hours 26 minutes 37 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9454
# Remaining time: 0 days 3 hours 21 minutes 53 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9438
# Remaining time: 0 days 3 hours 17 minutes 10 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9454
# Remaining time: 0 days 3 hours 12 minutes 27 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.961
# Remaining time: 0 days 3 hours 07 minutes 50 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9629
# Remaining time: 0 days 3 hours 03 minutes 13 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9627
# Remaining time: 0 days 2 hours 58 minutes 36 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9629
# Remaining time: 0 days 2 hours 53 minutes 55 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9601
# Remaining time: 0 days 2 hours 49 minutes 14 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9343
# Remaining time: 0 days 2 hours 44 minutes 28 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.935
# Remaining time: 0 days 2 hours 39 minutes 44 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.936
# Remaining time: 0 days 2 hours 34 minutes 57 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9375
# Remaining time: 0 days 2 hours 30 minutes 13 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9356
# Remaining time: 0 days 2 hours 25 minutes 28 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9619
# Remaining time: 0 days 2 hours 20 minutes 44 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9593
# Remaining time: 0 days 2 hours 16 minutes 00 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.961
# Remaining time: 0 days 2 hours 11 minutes 14 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9586
# Remaining time: 0 days 2 hours 06 minutes 26 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9607
# Remaining time: 0 days 2 hours 01 minutes 40 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 0.5}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9107
# Remaining time: 0 days 1 hours 56 minutes 48 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9111
# Remaining time: 0 days 1 hours 51 minutes 57 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9113
# Remaining time: 0 days 1 hours 47 minutes 07 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9105
# Remaining time: 0 days 1 hours 42 minutes 16 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9092
# Remaining time: 0 days 1 hours 37 minutes 27 seconds
# Training for activation selu, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9765
# Remaining time: 0 days 1 hours 32 minutes 30 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9764
# Remaining time: 0 days 1 hours 27 minutes 34 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9767
# Remaining time: 0 days 1 hours 22 minutes 38 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9773
# Remaining time: 0 days 1 hours 17 minutes 44 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9766
# Remaining time: 0 days 1 hours 12 minutes 48 seconds
# Training for activation selu, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9734
# Remaining time: 0 days 1 hours 07 minutes 53 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9738
# Remaining time: 0 days 1 hours 02 minutes 57 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9763
# Remaining time: 0 days 0 hours 58 minutes 03 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9744
# Remaining time: 0 days 0 hours 53 minutes 09 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9753
# Remaining time: 0 days 0 hours 48 minutes 16 seconds
# Training for activation sigmoid, optimizer Adamax with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9773
# Remaining time: 0 days 0 hours 43 minutes 24 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9744
# Remaining time: 0 days 0 hours 38 minutes 33 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.9769
# Remaining time: 0 days 0 hours 33 minutes 41 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9765
# Remaining time: 0 days 0 hours 28 minutes 51 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9736
# Remaining time: 0 days 0 hours 24 minutes 01 seconds
# Training for activation sigmoid, optimizer sgd with config {'type': 'gaussian_noise', 'rate': 1.0}
# ------------------------------
# Experiment 0
# Test accuracy: 0.9475
# Remaining time: 0 days 0 hours 19 minutes 11 seconds
# ------------------------------
# Experiment 1
# Test accuracy: 0.9496
# Remaining time: 0 days 0 hours 14 minutes 23 seconds
# ------------------------------
# Experiment 2
# Test accuracy: 0.948
# Remaining time: 0 days 0 hours 09 minutes 34 seconds
# ------------------------------
# Experiment 3
# Test accuracy: 0.9482
# Remaining time: 0 days 0 hours 04 minutes 47 seconds
# ------------------------------
# Experiment 4
# Test accuracy: 0.9489
# Remaining time: 0 days 0 hours 00 minutes 00 seconds
